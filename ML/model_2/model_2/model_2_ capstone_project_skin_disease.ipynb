# %%
# Data Science Libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
import itertools
import random

# Visualization Libraries
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# TensorFlow Libraries
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras import Model
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import regularizers
from pathlib import Path
import os.path
import zipfile
from google.colab import drive
from sklearn.metrics import classification_report, confusion_matrix

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_path = '/content/drive/MyDrive/Capstone/skin_disease.zip'
extract_path = '/content/drive/MyDrive/Capstone'

# %%
# Create the extraction directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Unzip the dataset
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Verify the contents
print("Files extracted to:", extract_path)
# Out:
# Files extracted to: /content/drive/MyDrive/Capstone

# %%
#helper function
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py

# Import series of helper functions for our notebook
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, compare_historys, walk_through_dir, pred_and_plot
# Out:
# --2024-05-29 11:29:32--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2024-05-29 11:29:32 (107 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
skin_disease_dataset = '/content/drive/MyDrive/Capstone/skin_disease'
walk_through_dir(skin_disease_dataset)
# Out:
# There are 14 directories and 0 images in '/content/drive/MyDrive/Capstone/skin_disease'.
# There are 0 directories and 100 images in '/content/drive/MyDrive/Capstone/skin_disease/acne'.
# There are 0 directories and 271 images in '/content/drive/MyDrive/Capstone/skin_disease/basal_cell_carcinoma'.
# There are 0 directories and 100 images in '/content/drive/MyDrive/Capstone/skin_disease/benign_keratosis_like_lesions'.
# There are 0 directories and 170 images in '/content/drive/MyDrive/Capstone/skin_disease/chicken_pox'.
# There are 0 directories and 100 images in '/content/drive/MyDrive/Capstone/skin_disease/eksim'.
# There are 0 directories and 100 images in '/content/drive/MyDrive/Capstone/skin_disease/melanoctyic_nevi'.
# There are 0 directories and 247 images in '/content/drive/MyDrive/Capstone/skin_disease/melanoma'.
# There are 0 directories and 100 images in '/content/drive/MyDrive/Capstone/skin_disease/psoriasis_pictures_lichen_planus_and_related_diseases'.
# There are 0 directories and 104 images in '/content/drive/MyDrive/Capstone/skin_disease/ringworm'.
# There are 0 directories and 102 images in '/content/drive/MyDrive/Capstone/skin_disease/scabies'.
# There are 0 directories and 104 images in '/content/drive/MyDrive/Capstone/skin_disease/seborrheic_keratosis'.
# There are 0 directories and 138 images in '/content/drive/MyDrive/Capstone/skin_disease/shingles'.
# There are 0 directories and 100 images in '/content/drive/MyDrive/Capstone/skin_disease/urticaria_hives'.
# There are 0 directories and 100 images in '/content/drive/MyDrive/Capstone/skin_disease/warts_molluscum_and_other_viral_infections'.

# %%
img_directory = Path(skin_disease_dataset)
filepaths = list(img_directory.glob(r'**/*.JPG')) + list(img_directory.glob(r'**/*.jpg')) + list(img_directory.glob(r'**/*.png')) + list(img_directory.glob(r'**/*.png'))

labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# %%
image_df
# Out:
#                                                Filepath                 Label
# 0     /content/drive/MyDrive/Capstone/skin_disease/b...  basal_cell_carcinoma
# 1     /content/drive/MyDrive/Capstone/skin_disease/b...  basal_cell_carcinoma
# 2     /content/drive/MyDrive/Capstone/skin_disease/b...  basal_cell_carcinoma
# 3     /content/drive/MyDrive/Capstone/skin_disease/b...  basal_cell_carcinoma
# 4     /content/drive/MyDrive/Capstone/skin_disease/b...  basal_cell_carcinoma
# ...                                                 ...                   ...
# 2270  /content/drive/MyDrive/Capstone/skin_disease/u...       urticaria_hives
# 2271  /content/drive/MyDrive/Capstone/skin_disease/u...       urticaria_hives
# 2272  /content/drive/MyDrive/Capstone/skin_disease/u...       urticaria_hives
# 2273  /content/drive/MyDrive/Capstone/skin_disease/u...       urticaria_hives
# 2274  /content/drive/MyDrive/Capstone/skin_disease/u...       urticaria_hives
#
# [2275 rows x 2 columns]

# %%
# Display 8 pictures of the dataset with their labels
random_index = np.random.randint(0, len(image_df), 8)

fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 5),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    img = plt.imread(image_df['Filepath'].iloc[random_index[i]])
    ax.imshow(img)
    ax.set_title(image_df['Label'].iloc[random_index[i]])

plt.tight_layout()
plt.show()

# %%
#separate to training, validation, testing
training_dataset, testing_dataset = train_test_split(image_df, test_size=0.2, shuffle=True, random_state=1)

# %%
train_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input,
    validation_split=0.2
)

test_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input
)

# %%
training_images = train_generator.flow_from_dataframe(
dataframe = training_dataset,
x_col='Filepath',
y_col = 'Label',
target_size=(224,224),
color_mode='rgb',
class_mode='categorical',
batch_size=32,
shuffle=True,
seed=42,
subset='training')

validation_images = train_generator.flow_from_dataframe(
dataframe = training_dataset,
x_col='Filepath',
y_col = 'Label',
target_size=(224,224),
color_mode='rgb',
class_mode='categorical',
batch_size=32,
shuffle=True,
seed=42,
subset='validation')

test_images = test_generator.flow_from_dataframe(
dataframe = testing_dataset,
x_col='Filepath',
y_col = 'Label',
target_size=(224,224),
color_mode='rgb',
class_mode='categorical',
batch_size=32,
shuffle=False)
# Out:
# Found 1456 validated image filenames belonging to 14 classes.
# Found 364 validated image filenames belonging to 14 classes.
# Found 455 validated image filenames belonging to 14 classes.

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(224,224),
    layers.experimental.preprocessing.Rescaling(1./255),
])

data_augmentation = keras.Sequential([
    preprocessing.RandomFlip("horizontal_and_vertical"),
    preprocessing.RandomZoom(0.3),
    preprocessing.RandomRotation(0.4),
    preprocessing.RandomWidth(0.3),
    preprocessing.RandomHeight(0.3)
], name="data_augmentation")

# %%
input_shape = (224,224,3)
Base_Model = tf.keras.applications.MobileNetV3Large(
input_shape=input_shape,
include_top = False,
    weights = 'imagenet',
    pooling='avg'
)
Base_Model.trainable = False

# %%
def build_model(base_model, num_classes):
    inputs = base_model.input
    x = data_augmentation(inputs)
    x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001))(base_model.output)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# Load the base model with pre-trained weights, exclude the top layers
base_model = tf.keras.applications.MobileNetV3Small(include_top=False, pooling='avg')
num_classes = 14
# Unfreeze the last few layers of the base model for fine-tuning
for layer in base_model.layers[-10:]:
    layer.trainable = True

# Build the model
model = build_model(base_model, num_classes)

# Compile the model
model.compile(
    optimizer=optimizers.Adam(0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Set up callbacks
early_stopping = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7)
tensorboard_callback = TensorBoard(log_dir="training_logs/skin_disease_classification")

# Fit the model
history = model.fit(
    training_images,
    steps_per_epoch=len(training_images),
    validation_data=validation_images,
    validation_steps=len(validation_images),
    epochs=100,
    callbacks=[
        early_stopping,
        reduce_lr,
        tensorboard_callback
    ]
)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/100
# 46/46 [==============================] - 67s 695ms/step - loss: 3.8359 - accuracy: 0.1003 - val_loss: 3.2128 - val_accuracy: 0.1813 - lr: 1.0000e-04
# Epoch 2/100
# 46/46 [==============================] - 25s 555ms/step - loss: 3.5504 - accuracy: 0.1401 - val_loss: 3.1448 - val_accuracy: 0.2060 - lr: 1.0000e-04
# Epoch 3/100
# 46/46 [==============================] - 25s 551ms/step - loss: 3.2874 - accuracy: 0.1937 - val_loss: 3.0578 - val_accuracy: 0.2500 - lr: 1.0000e-04
# Epoch 4/100
# 46/46 [==============================] - 25s 551ms/step - loss: 3.0571 - accuracy: 0.2418 - val_loss: 2.9322 - val_accuracy: 0.2967 - lr: 1.0000e-04
# Epoch 5/100
# 46/46 [==============================] - 26s 575ms/step - loss: 2.9161 - accuracy: 0.2891 - val_loss: 2.8346 - val_accuracy: 0.3407 - lr: 1.0000e-04
# Epoch 6/100
# 46/46 [==============================] - 25s 550ms/step - loss: 2.7385 - accuracy: 0.3283 - val_loss: 2.7246 - val_accuracy: 0.3874 - lr: 1.0000e-04
# Epoch 7/100
# 46/46 [==============================] - 26s 571ms/step - loss: 2.6286 - accuracy: 0.3805 - val_loss: 2.6304 - val_accuracy: 0.4258 - lr: 1.0000e-04
# Epoch 8/100
# 46/46 [==============================] - 25s 548ms/step - loss: 2.5109 - accuracy: 0.4018 - val_loss: 2.5693 - val_accuracy: 0.4231 - lr: 1.0000e-04
# Epoch 9/100
# 46/46 [==============================] - 25s 552ms/step - loss: 2.4095 - accuracy: 0.4320 - val_loss: 2.4976 - val_accuracy: 0.4533 - lr: 1.0000e-04
# Epoch 10/100
# 46/46 [==============================] - 26s 568ms/step - loss: 2.3833 - accuracy: 0.4581 - val_loss: 2.4404 - val_accuracy: 0.4670 - lr: 1.0000e-04
# Epoch 11/100
# 46/46 [==============================] - 26s 557ms/step - loss: 2.2420 - accuracy: 0.5034 - val_loss: 2.3695 - val_accuracy: 0.4863 - lr: 1.0000e-04
# Epoch 12/100
# 46/46 [==============================] - 25s 555ms/step - loss: 2.2121 - accuracy: 0.5179 - val_loss: 2.2626 - val_accuracy: 0.5385 - lr: 1.0000e-04
# Epoch 13/100
# 46/46 [==============================] - 26s 556ms/step - loss: 2.2087 - accuracy: 0.5206 - val_loss: 2.1938 - val_accuracy: 0.5467 - lr: 1.0000e-04
# Epoch 14/100
# 46/46 [==============================] - 26s 559ms/step - loss: 2.0997 - accuracy: 0.5701 - val_loss: 2.1499 - val_accuracy: 0.5687 - lr: 1.0000e-04
# Epoch 15/100
# 46/46 [==============================] - 25s 545ms/step - loss: 2.0208 - accuracy: 0.5742 - val_loss: 2.1050 - val_accuracy: 0.5742 - lr: 1.0000e-04
# Epoch 16/100
# 46/46 [==============================] - 26s 568ms/step - loss: 2.0176 - accuracy: 0.5790 - val_loss: 2.0599 - val_accuracy: 0.5934 - lr: 1.0000e-04
# Epoch 17/100
# 46/46 [==============================] - 26s 559ms/step - loss: 1.9398 - accuracy: 0.6277 - val_loss: 1.9739 - val_accuracy: 0.6374 - lr: 1.0000e-04
# Epoch 18/100
# 46/46 [==============================] - 25s 553ms/step - loss: 1.9196 - accuracy: 0.6243 - val_loss: 1.9195 - val_accuracy: 0.6538 - lr: 1.0000e-04
# Epoch 19/100
# 46/46 [==============================] - 25s 548ms/step - loss: 1.8897 - accuracy: 0.6339 - val_loss: 1.8785 - val_accuracy: 0.6621 - lr: 1.0000e-04
# Epoch 20/100
# 46/46 [==============================] - 26s 558ms/step - loss: 1.8180 - accuracy: 0.6593 - val_loss: 1.8554 - val_accuracy: 0.6731 - lr: 1.0000e-04
# Epoch 21/100
# 46/46 [==============================] - 25s 551ms/step - loss: 1.7863 - accuracy: 0.6717 - val_loss: 1.8093 - val_accuracy: 0.6841 - lr: 1.0000e-04
# Epoch 22/100
# 46/46 [==============================] - 26s 557ms/step - loss: 1.7357 - accuracy: 0.6820 - val_loss: 1.7451 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 23/100
# 46/46 [==============================] - 30s 664ms/step - loss: 1.7139 - accuracy: 0.7012 - val_loss: 1.6943 - val_accuracy: 0.7005 - lr: 1.0000e-04
# Epoch 24/100
# 46/46 [==============================] - 27s 583ms/step - loss: 1.6511 - accuracy: 0.7191 - val_loss: 1.6535 - val_accuracy: 0.7198 - lr: 1.0000e-04
# Epoch 25/100
# 46/46 [==============================] - 25s 555ms/step - loss: 1.6342 - accuracy: 0.7280 - val_loss: 1.6147 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 26/100
# 46/46 [==============================] - 25s 547ms/step - loss: 1.5931 - accuracy: 0.7349 - val_loss: 1.5975 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 27/100
# 46/46 [==============================] - 26s 557ms/step - loss: 1.5695 - accuracy: 0.7486 - val_loss: 1.5621 - val_accuracy: 0.7692 - lr: 1.0000e-04
# Epoch 28/100
# 46/46 [==============================] - 25s 542ms/step - loss: 1.5743 - accuracy: 0.7438 - val_loss: 1.5106 - val_accuracy: 0.7720 - lr: 1.0000e-04
# Epoch 29/100
# 46/46 [==============================] - 25s 538ms/step - loss: 1.4890 - accuracy: 0.7727 - val_loss: 1.4688 - val_accuracy: 0.7912 - lr: 1.0000e-04
# Epoch 30/100
# 46/46 [==============================] - 26s 563ms/step - loss: 1.4944 - accuracy: 0.7610 - val_loss: 1.4614 - val_accuracy: 0.7995 - lr: 1.0000e-04
# Epoch 31/100
# 46/46 [==============================] - 25s 554ms/step - loss: 1.4940 - accuracy: 0.7706 - val_loss: 1.4299 - val_accuracy: 0.8077 - lr: 1.0000e-04
# Epoch 32/100
# 46/46 [==============================] - 26s 567ms/step - loss: 1.4439 - accuracy: 0.7988 - val_loss: 1.4111 - val_accuracy: 0.8214 - lr: 1.0000e-04
# Epoch 33/100
# 46/46 [==============================] - 28s 607ms/step - loss: 1.4286 - accuracy: 0.7995 - val_loss: 1.3851 - val_accuracy: 0.8159 - lr: 1.0000e-04
# Epoch 34/100
# 46/46 [==============================] - 26s 559ms/step - loss: 1.3961 - accuracy: 0.8125 - val_loss: 1.3421 - val_accuracy: 0.8324 - lr: 1.0000e-04
# Epoch 35/100
# 46/46 [==============================] - 25s 543ms/step - loss: 1.3895 - accuracy: 0.7988 - val_loss: 1.3202 - val_accuracy: 0.8462 - lr: 1.0000e-04
# Epoch 36/100
# 46/46 [==============================] - 26s 557ms/step - loss: 1.3309 - accuracy: 0.8297 - val_loss: 1.3049 - val_accuracy: 0.8462 - lr: 1.0000e-04
# Epoch 37/100
# 46/46 [==============================] - 25s 553ms/step - loss: 1.3012 - accuracy: 0.8455 - val_loss: 1.2840 - val_accuracy: 0.8489 - lr: 1.0000e-04
# Epoch 38/100
# 46/46 [==============================] - 26s 559ms/step - loss: 1.3151 - accuracy: 0.8317 - val_loss: 1.2409 - val_accuracy: 0.8489 - lr: 1.0000e-04
# Epoch 39/100
# 46/46 [==============================] - 25s 537ms/step - loss: 1.2782 - accuracy: 0.8455 - val_loss: 1.2083 - val_accuracy: 0.8489 - lr: 1.0000e-04
# Epoch 40/100
# 46/46 [==============================] - 25s 554ms/step - loss: 1.2423 - accuracy: 0.8571 - val_loss: 1.1900 - val_accuracy: 0.8544 - lr: 1.0000e-04
# Epoch 41/100
# 46/46 [==============================] - 24s 524ms/step - loss: 1.2281 - accuracy: 0.8626 - val_loss: 1.1764 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 42/100
# 46/46 [==============================] - 26s 569ms/step - loss: 1.2251 - accuracy: 0.8647 - val_loss: 1.1694 - val_accuracy: 0.8599 - lr: 1.0000e-04
# Epoch 43/100
# 46/46 [==============================] - 25s 553ms/step - loss: 1.2103 - accuracy: 0.8626 - val_loss: 1.1559 - val_accuracy: 0.8681 - lr: 1.0000e-04
# Epoch 44/100
# 46/46 [==============================] - 25s 545ms/step - loss: 1.2010 - accuracy: 0.8633 - val_loss: 1.1624 - val_accuracy: 0.8709 - lr: 1.0000e-04
# Epoch 45/100
# 46/46 [==============================] - 25s 540ms/step - loss: 1.1756 - accuracy: 0.8688 - val_loss: 1.1402 - val_accuracy: 0.8709 - lr: 1.0000e-04
# Epoch 46/100
# 46/46 [==============================] - 25s 556ms/step - loss: 1.1372 - accuracy: 0.8846 - val_loss: 1.1186 - val_accuracy: 0.8736 - lr: 1.0000e-04
# Epoch 47/100
# 46/46 [==============================] - 25s 534ms/step - loss: 1.1222 - accuracy: 0.8970 - val_loss: 1.0939 - val_accuracy: 0.8709 - lr: 1.0000e-04
# Epoch 48/100
# 46/46 [==============================] - 25s 544ms/step - loss: 1.0997 - accuracy: 0.9038 - val_loss: 1.0759 - val_accuracy: 0.8736 - lr: 1.0000e-04
# Epoch 49/100
# 46/46 [==============================] - 25s 547ms/step - loss: 1.0877 - accuracy: 0.9004 - val_loss: 1.0803 - val_accuracy: 0.8736 - lr: 1.0000e-04
# Epoch 50/100
# 46/46 [==============================] - 25s 551ms/step - loss: 1.0607 - accuracy: 0.9073 - val_loss: 1.0704 - val_accuracy: 0.8764 - lr: 1.0000e-04
# Epoch 51/100
# 46/46 [==============================] - 25s 548ms/step - loss: 1.0544 - accuracy: 0.9080 - val_loss: 1.0483 - val_accuracy: 0.8791 - lr: 1.0000e-04
# Epoch 52/100
# 46/46 [==============================] - 24s 528ms/step - loss: 1.0284 - accuracy: 0.9224 - val_loss: 1.0493 - val_accuracy: 0.8791 - lr: 1.0000e-04
# Epoch 53/100
# 46/46 [==============================] - 25s 545ms/step - loss: 1.0578 - accuracy: 0.9107 - val_loss: 1.0402 - val_accuracy: 0.8819 - lr: 1.0000e-04
# Epoch 54/100
# 46/46 [==============================] - 25s 553ms/step - loss: 0.9936 - accuracy: 0.9265 - val_loss: 1.0228 - val_accuracy: 0.8819 - lr: 1.0000e-04
# Epoch 55/100
# 46/46 [==============================] - 25s 536ms/step - loss: 1.0119 - accuracy: 0.9169 - val_loss: 1.0138 - val_accuracy: 0.8929 - lr: 1.0000e-04
# Epoch 56/100
# 46/46 [==============================] - 25s 555ms/step - loss: 0.9944 - accuracy: 0.9265 - val_loss: 1.0121 - val_accuracy: 0.8901 - lr: 1.0000e-04
# Epoch 57/100
# 46/46 [==============================] - 25s 548ms/step - loss: 0.9816 - accuracy: 0.9299 - val_loss: 1.0095 - val_accuracy: 0.8956 - lr: 1.0000e-04
# Epoch 58/100
# 46/46 [==============================] - 25s 539ms/step - loss: 0.9599 - accuracy: 0.9409 - val_loss: 0.9868 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 59/100
# 46/46 [==============================] - 26s 575ms/step - loss: 0.9350 - accuracy: 0.9444 - val_loss: 0.9812 - val_accuracy: 0.8956 - lr: 1.0000e-04
# Epoch 60/100
# 46/46 [==============================] - 26s 557ms/step - loss: 0.9196 - accuracy: 0.9444 - val_loss: 0.9754 - val_accuracy: 0.8956 - lr: 1.0000e-04
# Epoch 61/100
# 46/46 [==============================] - 25s 550ms/step - loss: 0.9162 - accuracy: 0.9430 - val_loss: 0.9657 - val_accuracy: 0.9038 - lr: 1.0000e-04
# Epoch 62/100
# 46/46 [==============================] - 25s 551ms/step - loss: 0.9057 - accuracy: 0.9444 - val_loss: 0.9617 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 63/100
# 46/46 [==============================] - 25s 537ms/step - loss: 0.9059 - accuracy: 0.9396 - val_loss: 0.9625 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 64/100
# 46/46 [==============================] - 25s 547ms/step - loss: 0.9057 - accuracy: 0.9478 - val_loss: 0.9635 - val_accuracy: 0.9038 - lr: 1.0000e-04
# Epoch 65/100
# 46/46 [==============================] - 24s 527ms/step - loss: 0.9002 - accuracy: 0.9396 - val_loss: 0.9627 - val_accuracy: 0.9066 - lr: 1.0000e-04
# Epoch 66/100
# 46/46 [==============================] - 25s 554ms/step - loss: 0.8649 - accuracy: 0.9574 - val_loss: 0.9684 - val_accuracy: 0.9066 - lr: 5.0000e-05
# Epoch 67/100
# 46/46 [==============================] - 27s 582ms/step - loss: 0.8827 - accuracy: 0.9512 - val_loss: 0.9609 - val_accuracy: 0.9011 - lr: 5.0000e-05
# Epoch 68/100
# 46/46 [==============================] - 26s 557ms/step - loss: 0.8773 - accuracy: 0.9574 - val_loss: 0.9641 - val_accuracy: 0.9011 - lr: 5.0000e-05
# Epoch 69/100
# 46/46 [==============================] - 26s 559ms/step - loss: 0.8609 - accuracy: 0.9595 - val_loss: 0.9565 - val_accuracy: 0.9121 - lr: 5.0000e-05
# Epoch 70/100
# 46/46 [==============================] - 25s 539ms/step - loss: 0.8520 - accuracy: 0.9533 - val_loss: 0.9656 - val_accuracy: 0.9066 - lr: 5.0000e-05
# Epoch 71/100
# 46/46 [==============================] - 25s 543ms/step - loss: 0.8462 - accuracy: 0.9615 - val_loss: 0.9445 - val_accuracy: 0.9093 - lr: 5.0000e-05
# Epoch 72/100
# 46/46 [==============================] - 25s 549ms/step - loss: 0.8710 - accuracy: 0.9464 - val_loss: 0.9348 - val_accuracy: 0.9093 - lr: 5.0000e-05
# Epoch 73/100
# 46/46 [==============================] - 25s 553ms/step - loss: 0.8282 - accuracy: 0.9622 - val_loss: 0.9303 - val_accuracy: 0.9121 - lr: 5.0000e-05
# Epoch 74/100
# 46/46 [==============================] - 25s 534ms/step - loss: 0.8394 - accuracy: 0.9560 - val_loss: 0.9289 - val_accuracy: 0.9176 - lr: 5.0000e-05
# Epoch 75/100
# 46/46 [==============================] - 25s 546ms/step - loss: 0.8250 - accuracy: 0.9643 - val_loss: 0.9279 - val_accuracy: 0.9121 - lr: 5.0000e-05
# Epoch 76/100
# 46/46 [==============================] - 26s 556ms/step - loss: 0.8423 - accuracy: 0.9588 - val_loss: 0.9174 - val_accuracy: 0.9121 - lr: 5.0000e-05
# Epoch 77/100
# 46/46 [==============================] - 27s 582ms/step - loss: 0.8215 - accuracy: 0.9636 - val_loss: 0.9177 - val_accuracy: 0.9203 - lr: 5.0000e-05
# Epoch 78/100
# 46/46 [==============================] - 25s 537ms/step - loss: 0.8307 - accuracy: 0.9602 - val_loss: 0.9199 - val_accuracy: 0.9093 - lr: 5.0000e-05
# Epoch 79/100
# 46/46 [==============================] - 25s 555ms/step - loss: 0.8241 - accuracy: 0.9547 - val_loss: 0.9243 - val_accuracy: 0.9038 - lr: 5.0000e-05
# Epoch 80/100
# 46/46 [==============================] - 25s 531ms/step - loss: 0.8402 - accuracy: 0.9554 - val_loss: 0.9275 - val_accuracy: 0.9093 - lr: 2.5000e-05
# Epoch 81/100
# 46/46 [==============================] - 25s 547ms/step - loss: 0.8073 - accuracy: 0.9677 - val_loss: 0.9261 - val_accuracy: 0.9066 - lr: 2.5000e-05
# Epoch 82/100
# 46/46 [==============================] - 26s 557ms/step - loss: 0.8088 - accuracy: 0.9636 - val_loss: 0.9294 - val_accuracy: 0.9066 - lr: 2.5000e-05
# Epoch 83/100
# 46/46 [==============================] - 25s 554ms/step - loss: 0.8049 - accuracy: 0.9677 - val_loss: 0.9275 - val_accuracy: 0.9066 - lr: 1.2500e-05
# Epoch 84/100
# 46/46 [==============================] - 26s 557ms/step - loss: 0.7928 - accuracy: 0.9684 - val_loss: 0.9244 - val_accuracy: 0.9066 - lr: 1.2500e-05
# Epoch 85/100
# 46/46 [==============================] - 28s 602ms/step - loss: 0.7951 - accuracy: 0.9705 - val_loss: 0.9222 - val_accuracy: 0.9066 - lr: 1.2500e-05
# Epoch 86/100
# 46/46 [==============================] - 26s 557ms/step - loss: 0.8060 - accuracy: 0.9670 - val_loss: 0.9208 - val_accuracy: 0.9066 - lr: 6.2500e-06

# %%
results = model.evaluate(test_images, verbose=2)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# 15/15 - 7s - loss: 0.9150 - accuracy: 0.9033 - 7s/epoch - 493ms/step
#     Test Loss: 0.91503
# Test Accuracy: 90.33%

# %%
plot_loss_curves(history)

# %%
model.save('train_model_mobileNetV3_tes.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
 converter = tf.lite.TFLiteConverter.from_keras_model(model)
 tflite_model = converter.convert()

 with open('model.tflite_2', 'wb') as f:
   f.write(tflite_model)

# %%
history.history #Return Dictionary of history
# Out:
# {'loss': [3.835904359817505,
#   3.550398588180542,
#   3.287433385848999,
#   3.057093381881714,
#   2.916050910949707,
#   2.738454580307007,
#   2.62861704826355,
#   2.510864019393921,
#   2.4094631671905518,
#   2.383289098739624,
#   2.242039680480957,
#   2.212076425552368,
#   2.2086591720581055,
#   2.099669933319092,
#   2.0208353996276855,
#   2.017646312713623,
#   1.9398497343063354,
#   1.9196019172668457,
#   1.8897438049316406,
#   1.8179535865783691,
#   1.7862941026687622,
#   1.7357063293457031,
#   1.7139047384262085,
#   1.6510930061340332,
#   1.6341772079467773,
#   1.593124508857727,
#   1.5695292949676514,
#   1.5743194818496704,
#   1.4889593124389648,
#   1.494417428970337,
#   1.4939711093902588,
#   1.4438799619674683,
#   1.4286446571350098,
#   1.3961306810379028,
#   1.3894860744476318,
#   1.3309195041656494,
#   1.3012473583221436,
#   1.315106987953186,
#   1.2782269716262817,
#   1.2422502040863037,
#   1.228136420249939,
#   1.2250680923461914,
#   1.2103261947631836,
#   1.200960397720337,
#   1.175601840019226,
#   1.1372162103652954,
#   1.1222238540649414,
#   1.0997217893600464,
#   1.0876824855804443,
#   1.0606622695922852,
#   1.0543662309646606,
#   1.0284249782562256,
#   1.0577892065048218,
#   0.9935693144798279,
#   1.011896014213562,
#   0.9944377541542053,
#   0.9815638661384583,
#   0.959919273853302,
#   0.935032844543457,
#   0.9195969104766846,
#   0.9162026643753052,
#   0.9056544303894043,
#   0.9059293270111084,
#   0.9057093858718872,
#   0.9002229571342468,
#   0.8648620247840881,
#   0.8826935291290283,
#   0.8772832751274109,
#   0.860914945602417,
#   0.85197514295578,
#   0.846214234828949,
#   0.8709679841995239,
#   0.8281760811805725,
#   0.8393951058387756,
#   0.8249995708465576,
#   0.8423030972480774,
#   0.8215272426605225,
#   0.8307176232337952,
#   0.8240982890129089,
#   0.8401569724082947,
#   0.8073461055755615,
#   0.8088284730911255,
#   0.8048710823059082,
#   0.7928237318992615,
#   0.7951094508171082,
#   0.806011438369751],
#  'accuracy': [0.10027472674846649,
#   0.14010989665985107,
#   0.19368131458759308,
#   0.24175824224948883,
#   0.28914836049079895,
#   0.3282966911792755,
#   0.38049450516700745,
#   0.4017857015132904,
#   0.43200549483299255,
#   0.4581044018268585,
#   0.5034340620040894,
#   0.5178571343421936,
#   0.5206043720245361,
#   0.5700549483299255,
#   0.5741758346557617,
#   0.5789835453033447,
#   0.6277472376823425,
#   0.6243131756782532,
#   0.6339285969734192,
#   0.6593406796455383,
#   0.6717032790184021,
#   0.6820054650306702,
#   0.7012362480163574,
#   0.719093382358551,
#   0.7280219793319702,
#   0.7348901033401489,
#   0.7486263513565063,
#   0.7438187003135681,
#   0.7726648449897766,
#   0.7609890103340149,
#   0.7706043720245361,
#   0.7987637519836426,
#   0.7994505763053894,
#   0.8125,
#   0.7987637519836426,
#   0.8296703100204468,
#   0.8454670310020447,
#   0.8317307829856873,
#   0.8454670310020447,
#   0.8571428656578064,
#   0.8626373410224915,
#   0.8646978139877319,
#   0.8626373410224915,
#   0.8633241653442383,
#   0.8688187003135681,
#   0.8846153616905212,
#   0.8969780206680298,
#   0.9038461446762085,
#   0.9004120826721191,
#   0.9072802066802979,
#   0.9079670310020447,
#   0.9223901033401489,
#   0.9107142686843872,
#   0.9265109896659851,
#   0.9168956279754639,
#   0.9265109896659851,
#   0.9299450516700745,
#   0.9409340620040894,
#   0.9443681240081787,
#   0.9443681240081787,
#   0.9429945349693298,
#   0.9443681240081787,
#   0.9395604133605957,
#   0.9478021860122681,
#   0.9395604133605957,
#   0.9574176073074341,
#   0.9512362480163574,
#   0.9574176073074341,
#   0.9594780206680298,
#   0.9532967209815979,
#   0.9615384340286255,
#   0.9464285969734192,
#   0.9622252583503723,
#   0.9560439586639404,
#   0.9642857313156128,
#   0.958791196346283,
#   0.963598906993866,
#   0.9601648449897766,
#   0.9546703100204468,
#   0.9553571343421936,
#   0.9677197933197021,
#   0.963598906993866,
#   0.9677197933197021,
#   0.968406617641449,
#   0.9704670310020447,
#   0.9670329689979553],
#  'val_loss': [3.2127811908721924,
#   3.1448140144348145,
#   3.0577962398529053,
#   2.9321653842926025,
#   2.8345677852630615,
#   2.724608898162842,
#   2.630398988723755,
#   2.5692789554595947,
#   2.4976041316986084,
#   2.440419912338257,
#   2.369460344314575,
#   2.2625536918640137,
#   2.193837881088257,
#   2.149901866912842,
#   2.1050240993499756,
#   2.0599164962768555,
#   1.973917007446289,
#   1.9195120334625244,
#   1.8785161972045898,
#   1.855412244796753,
#   1.8092671632766724,
#   1.7450839281082153,
#   1.6942514181137085,
#   1.653497338294983,
#   1.6147180795669556,
#   1.597493290901184,
#   1.5621472597122192,
#   1.5106250047683716,
#   1.4687614440917969,
#   1.4614254236221313,
#   1.4299360513687134,
#   1.4110652208328247,
#   1.385055661201477,
#   1.3421423435211182,
#   1.3202357292175293,
#   1.304906964302063,
#   1.2840484380722046,
#   1.2408654689788818,
#   1.2082761526107788,
#   1.1899605989456177,
#   1.1764498949050903,
#   1.169414758682251,
#   1.1558878421783447,
#   1.1623812913894653,
#   1.1402008533477783,
#   1.1185951232910156,
#   1.093879222869873,
#   1.075905442237854,
#   1.080282211303711,
#   1.0703792572021484,
#   1.0482529401779175,
#   1.0493258237838745,
#   1.040169358253479,
#   1.0227617025375366,
#   1.013799786567688,
#   1.0121396780014038,
#   1.0095218420028687,
#   0.9867902398109436,
#   0.9812192916870117,
#   0.9754071235656738,
#   0.9657467603683472,
#   0.9616639614105225,
#   0.9625194668769836,
#   0.9635162949562073,
#   0.9626937508583069,
#   0.9683915972709656,
#   0.960932731628418,
#   0.9641498923301697,
#   0.9565367102622986,
#   0.9655845761299133,
#   0.9444711804389954,
#   0.9347797632217407,
#   0.9303333759307861,
#   0.9289029240608215,
#   0.9279430508613586,
#   0.9173775911331177,
#   0.9176551103591919,
#   0.9198523759841919,
#   0.9243485331535339,
#   0.9274922609329224,
#   0.9260926842689514,
#   0.9294472932815552,
#   0.9275048971176147,
#   0.9244049191474915,
#   0.9222334027290344,
#   0.9207515716552734],
#  'val_accuracy': [0.18131868541240692,
#   0.20604395866394043,
#   0.25,
#   0.2967033088207245,
#   0.34065935015678406,
#   0.38736262917518616,
#   0.4258241653442383,
#   0.42307692766189575,
#   0.4532966911792755,
#   0.4670329689979553,
#   0.4862637221813202,
#   0.5384615659713745,
#   0.5467032790184021,
#   0.5686812996864319,
#   0.5741758346557617,
#   0.593406617641449,
#   0.6373626589775085,
#   0.6538461446762085,
#   0.6620879173278809,
#   0.6730769276618958,
#   0.6840659379959106,
#   0.692307710647583,
#   0.7005494236946106,
#   0.7197802066802979,
#   0.75,
#   0.75,
#   0.7692307829856873,
#   0.7719780206680298,
#   0.791208803653717,
#   0.7994505763053894,
#   0.807692289352417,
#   0.8214285969734192,
#   0.8159340620040894,
#   0.8324176073074341,
#   0.8461538553237915,
#   0.8461538553237915,
#   0.848901093006134,
#   0.848901093006134,
#   0.848901093006134,
#   0.8543956279754639,
#   0.8571428656578064,
#   0.8598901033401489,
#   0.8681318759918213,
#   0.8708791136741638,
#   0.8708791136741638,
#   0.8736263513565063,
#   0.8708791136741638,
#   0.8736263513565063,
#   0.8736263513565063,
#   0.8763736486434937,
#   0.8791208863258362,
#   0.8791208863258362,
#   0.8818681240081787,
#   0.8818681240081787,
#   0.8928571343421936,
#   0.8901098966598511,
#   0.8956043720245361,
#   0.901098906993866,
#   0.8956043720245361,
#   0.8956043720245361,
#   0.9038461446762085,
#   0.901098906993866,
#   0.901098906993866,
#   0.9038461446762085,
#   0.906593382358551,
#   0.906593382358551,
#   0.901098906993866,
#   0.901098906993866,
#   0.9120879173278809,
#   0.906593382358551,
#   0.9093406796455383,
#   0.9093406796455383,
#   0.9120879173278809,
#   0.9175823926925659,
#   0.9120879173278809,
#   0.9120879173278809,
#   0.9203296899795532,
#   0.9093406796455383,
#   0.9038461446762085,
#   0.9093406796455383,
#   0.906593382358551,
#   0.906593382358551,
#   0.906593382358551,
#   0.906593382358551,
#   0.906593382358551,
#   0.906593382358551],
#  'lr': [1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   5e-05,
#   2.5e-05,
#   2.5e-05,
#   2.5e-05,
#   1.25e-05,
#   1.25e-05,
#   1.25e-05,
#   6.25e-06]}

# %%
# Convert history.history to a JSON-serializable format
history_dict = {key: [float(val) for val in values] for key, values in history.history.items()}

# Save the history to a JSON file
import json
with open('train_hist_mobileNetV3_new2.json', 'w') as f:
    json.dump(history_dict, f)

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
print("Validation set Accuracy: {} %".format(history.history['val_accuracy'][-1]*100))
# Out:
# Validation set Accuracy: 90.6593382358551 %

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (training_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')
# Out:
# 15/15 [==============================] - 6s 426ms/step
# The first 5 predictions: ['acne', 'basal_cell_carcinoma', 'ringworm', 'shingles', 'eksim']

# %%
  # Display 15 random pictures from the dataset with their labels
random_index = np.random.randint(0, len(testing_dataset) - 1, 15)
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(25, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(testing_dataset.Filepath.iloc[random_index[i]]))
    if testing_dataset.Label.iloc[random_index[i]] == pred[random_index[i]]:
      color = "green"
    else:
      color = "red"
    ax.set_title(f"True: {testing_dataset.Label.iloc[random_index[i]]}\nPredicted: {pred[random_index[i]]}", color=color)
plt.show()
plt.tight_layout()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
y_test = list(testing_dataset.Label)
print(classification_report(y_test, pred))
# Out:
#                                                        precision    recall  f1-score   support
#
#                                                  acne       0.84      0.95      0.89        38
#                                  basal_cell_carcinoma       0.91      0.89      0.90        46
#                         benign_keratosis_like_lesions       0.86      0.83      0.84        23
#                                           chicken_pox       1.00      0.96      0.98        27
#                                                 eksim       0.93      0.86      0.89        29
#                                      melanoctyic_nevi       0.67      0.69      0.68        26
#                                              melanoma       0.90      0.94      0.92        48
# psoriasis_pictures_lichen_planus_and_related_diseases       0.86      0.71      0.77        17
#                                              ringworm       0.95      0.87      0.91        23
#                                               scabies       0.94      1.00      0.97        46
#                                  seborrheic_keratosis       1.00      0.98      0.99        43
#                                              shingles       1.00      0.97      0.98        31
#                                       urticaria_hives       0.94      0.94      0.94        34
#            warts_molluscum_and_other_viral_infections       0.76      0.79      0.78        24
#
#                                              accuracy                           0.90       455
#                                             macro avg       0.90      0.88      0.89       455
#                                          weighted avg       0.91      0.90      0.90       455

# %%
import tensorflow as tf
import pathlib

# Specify the correct path to your model
model_path = '/content/drive/MyDrive/Capstone/train_model_mobileNetV3.h5'

# Load the Keras model
try:
    model = tf.keras.models.load_model(model_path)
except OSError as e:
    print(f"Error loading model: {e}")

# Convert the Keras model to TFLite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Specify the file name and path for the TFLite model
tflite_model_file = pathlib.Path('/content/drive/MyDrive/Capstone/train_model_mobileNetV3_.tflite')

# Save the TFLite model to a file
tflite_model_file.write_bytes(tflite_model)

print(f"TFLite model saved to: {tflite_model_file}")
# Out:
# Error loading model: No file or directory found at /content/drive/MyDrive/Capstone/train_model_mobileNetV3.h5
# TFLite model saved to: /content/drive/MyDrive/Capstone/train_model_mobileNetV3_.tflite
